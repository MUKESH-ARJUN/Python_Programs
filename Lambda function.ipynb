# %%
L = [1, 2, 3, 4, 5, 6, 7, 8, 9, 0]

result = list(map(lambda x: 'even' if x**2 % 2 == 0 else 'odd', L))

print(result)
# Out:
# ['odd', 'even', 'odd', 'even', 'odd', 'even', 'odd', 'even', 'odd', 'even']

# %%
D = {'key':'value'}

# %%
D.keys()
# Out:
# dict_keys(['key'])

# %%
L = [1, 2, 3, 4, 5, 6, 7, 8, 9, 0]


print(lambda X: if X%2==0 )

# %%
input_list = [1, 2, 3, 4, 5, 6, 7]
output_list = list(filter(lambda x: x % 2 == 0, map(lambda x: x**2, input_list)))

print(output_list)
# Out:
# [4, 16, 36]

# %%
input_list = [1, 2, 3, 4, 5, 6, 7]
output_list = list(filter(lambda x: x % 2 == 0, map(lambda x: x**2, input_list)))

print(output_list)

# %%
lambda x: x % 2 == 0, map(lambda x: x**2, input_list)

# %%
print(list(map(lambda x: x**2, input_list)))
# Out:
# [1, 4, 9, 16, 25, 36, 49]

# %%
print((list(filter(lambda x: x%2 == 0, input_list))))
# Out:
# [2, 4, 6]
